# %%
import seaborn as sns
import pandas as pd 
import numpy as np

diamonds_df = sns.load_dataset('diamonds')
diamonds_df.cut.unique()
diamonds_df.clarity.unique()

cut_count_table = pd.crosstab(index=diamonds_df['cut'],columns='count')
cut_count_table
cut_count_table.plot(kind='bar')
sns.catplot(x="cut", data=diamonds_df, aspect=1.5, kind="count", color="b")


#Mean Distribution in Bar Chart

sns.set(style='whitegrid')
ax= sns.barplot(x='cut', y='price', data=diamonds_df, estimator= np.mean)
ax= sns.barplot(x='cut', y='price', data=diamonds_df, estimator=np.mean, ci=68, order=['Ideal', 'Good', 'Very Good', 'Fair', 'Premium'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /var/folders/6w/zxx1vh4x65x012prsgwwd6p80000gn/T/ipykernel_50391/1017221390.py:18: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   ax= sns.barplot(x='cut', y='price', data=diamonds_df, estimator=np.mean, ci=68, order=['Ideal', 'Good', 'Very Good', 'Fair', 'Premium'])

# %%
#Creating Bar Plots Grouped by a Specific Feature

df= sns.load_dataset('diamonds')
ax= sns.barplot(x='cut', y='price', hue='color', data=df)
ax.legend(loc='upper center', ncol=7)
ax.set_xlabel('Cut', fontdict= {'fontsize': 15})
ax.set_xticklabels(ax.get_xticklabels(), fontsize=10, rotation=30)
# Out:
# [Text(0, 0, 'Ideal'),
#  Text(1, 0, 'Premium'),
#  Text(2, 0, 'Very Good'),
#  Text(3, 0, 'Good'),
#  Text(4, 0, 'Fair')]
